# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix

# %%
data = pd.read_csv('athlete_events.csv')

# %%
data
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271116 entries, 0 to 271115
# Data columns (total 15 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      271116 non-null  int64
#  1   Name    271116 non-null  object
#  2   Sex     271116 non-null  object
#  3   Age     261642 non-null  float64
#  4   Height  210945 non-null  float64
#  5   Weight  208241 non-null  float64
#  6   Team    271116 non-null  object
#  7   NOC     271116 non-null  object
#  8   Games   271116 non-null  object
#  9   Year    271116 non-null  int64
#  10  Season  271116 non-null  object
#  11  City    271116 non-null  object
#  12  Sport   271116 non-null  object
#  13  Event   271116 non-null  object
#  14  Medal   39783 non-null   object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 31.0+ MB

# %%
# Converting Medal to binary

# %%
data['Medal'] = data['Medal'].apply(lambda x: 1 if str(x) != 'nan' else 0)

# %%
data
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
# Cleaning deleting ID Name Season(as we are only doing for summer) & Games Column

# %%
data = data.drop(['ID', 'Name', 'Games', 'Season'], axis=1)

# %%
data
# Out:
#        Sex   Age  Height  Weight            Team  NOC  Year            City  \
# 0        M  24.0   180.0    80.0           China  CHN  1992       Barcelona
# 1        M  23.0   170.0    60.0           China  CHN  2012          London
# 2        M  24.0     NaN     NaN         Denmark  DEN  1920       Antwerpen
# 3        M  34.0     NaN     NaN  Denmark/Sweden  DEN  1900           Paris
# 4        F  21.0   185.0    82.0     Netherlands  NED  1988         Calgary
# ...     ..   ...     ...     ...             ...  ...   ...             ...
# 271111   M  29.0   179.0    89.0        Poland-1  POL  1976       Innsbruck
# 271112   M  27.0   176.0    59.0          Poland  POL  2014           Sochi
# 271113   M  27.0   176.0    59.0          Poland  POL  2014           Sochi
# 271114   M  30.0   185.0    96.0          Poland  POL  1998          Nagano
# 271115   M  34.0   185.0    96.0          Poland  POL  2002  Salt Lake City
#
# ...

# %%
# Removing NaN values

# %%
data.isna().sum()
# Out:
# Sex           0
# Age        9474
# Height    60171
# Weight    62875
# Team          0
# NOC           0
# Year          0
# City          0
# Sport         0
# Event         0
# Medal         0
# dtype: int64

# %%
data.groupby(['Medal', 'Sex']).mean()
# Out:
#                  Age      Height     Weight         Year
# Medal Sex
# 0     F    23.594127  167.354499  59.434446  1992.488865
#       M    26.239318  178.473681  75.170519  1974.116253
# 1     F    24.509167  170.474804  63.219378  1992.203324
#       M    26.497178  181.156113  79.203782  1966.741816

# %%
data.groupby(['Medal', 'Sex']).mean().astype(np.int)
# Out:
# C:\Users\abdul\anaconda3\envs\bukhari\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   """Entry point for launching an IPython kernel.
#            Age  Height  Weight  Year
# Medal Sex
# 0     F     23     167      59  1992
#       M     26     178      75  1974
# 1     F     24     170      63  1992
#       M     26     181      79  1966

# %%
for column in ['Age', 'Height', 'Weight']:
    data[column] = data.groupby(['Medal', 'Sex'])[column].apply(lambda x: x.fillna(x.mean()).astype(np.int))
# Out:
# C:\Users\abdul\anaconda3\envs\bukhari\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations

# %%
print("Total missing values:", data.isna().sum().sum())
# Out:
# Total missing values: 0

# %%
data
# Out:
#        Sex  Age  Height  Weight            Team  NOC  Year            City  \
# 0        M   24     180      80           China  CHN  1992       Barcelona
# 1        M   23     170      60           China  CHN  2012          London
# 2        M   24     178      75         Denmark  DEN  1920       Antwerpen
# 3        M   34     181      79  Denmark/Sweden  DEN  1900           Paris
# 4        F   21     185      82     Netherlands  NED  1988         Calgary
# ...     ..  ...     ...     ...             ...  ...   ...             ...
# 271111   M   29     179      89        Poland-1  POL  1976       Innsbruck
# 271112   M   27     176      59          Poland  POL  2014           Sochi
# 271113   M   27     176      59          Poland  POL  2014           Sochi
# 271114   M   30     185      96          Poland  POL  1998          Nagano
# 271115   M   34     185      96          Poland  POL  2002  Salt Lake City
#
# ...

# %%
# Encoding Non Numeric Columns

# %%
data.select_dtypes('object')
# Out:
#        Sex            Team  NOC            City          Sport  \
# 0        M           China  CHN       Barcelona     Basketball
# 1        M           China  CHN          London           Judo
# 2        M         Denmark  DEN       Antwerpen       Football
# 3        M  Denmark/Sweden  DEN           Paris     Tug-Of-War
# 4        F     Netherlands  NED         Calgary  Speed Skating
# ...     ..             ...  ...             ...            ...
# 271111   M        Poland-1  POL       Innsbruck           Luge
# 271112   M          Poland  POL           Sochi    Ski Jumping
# 271113   M          Poland  POL           Sochi    Ski Jumping
# 271114   M          Poland  POL          Nagano      Bobsleigh
# 271115   M          Poland  POL  Salt Lake City      Bobsleigh
#
#                                            Event
# 0                    Basketball Men's Basketball
# 1                   Judo Men's Extra-Lightweight
# 2                        Football Men's Football
# ...

# %%
print("Non-numeric columns:", len(data.select_dtypes('object').columns))
# Out:
# Non-numeric columns: 6

# %%
{column: len(data[column].unique()) for column in data.select_dtypes('object').columns}
# Out:
# {'Sex': 2, 'Team': 1184, 'NOC': 230, 'City': 42, 'Sport': 66, 'Event': 765}

# %%
def binary_encode(df, columns, positive_values):
    df = df.copy()
    for column, positive_value in zip(columns, positive_values):
        df[column] = df[column].apply(lambda x: 1 if x == positive_value else 0)
    return df

def onehot_encode(df, columns, prefixes):
    df = df.copy()
    for column, prefix in zip(columns, prefixes):
        dummies = pd.get_dummies(df[column], prefix=prefix)
        df = pd.concat([df, dummies], axis=1)
        df = df.drop(column, axis=1)
    return df

# %%
data = binary_encode(
    data,
    columns=['Sex'],
    positive_values=['M']
)

# %%
data = onehot_encode(
    data,
    columns=['Team', 'NOC', 'City', 'Sport', 'Event'],
    prefixes=['T', 'N', 'C', 'S', 'E']
)

# %%
print("Non-numeric columns:", len(data.select_dtypes('object').columns))
# Out:
# Non-numeric columns: 0

# %%
#Visualisation

# %%
data
# Out:
#         Sex  Age  Height  Weight  Year  Medal  T_30. Februar  \
# 0         1   24     180      80  1992      0              0
# 1         1   23     170      60  2012      0              0
# 2         1   24     178      75  1920      0              0
# 3         1   34     181      79  1900      1              0
# 4         0   21     185      82  1988      0              0
# ...     ...  ...     ...     ...   ...    ...            ...
# 271111    1   29     179      89  1976      0              0
# 271112    1   27     176      59  2014      0              0
# 271113    1   27     176      59  2014      0              0
# 271114    1   30     185      96  1998      0              0
# 271115    1   34     185      96  2002      0              0
#
#         T_A North American Team  T_Acipactli  T_Acturus  ...  \
# 0                             0            0          0  ...
# 1                             0            0          0  ...
# ...

# %%
#Dropping one hot encoded data columns

# %%
data.loc[:, :'Medal']
# Out:
#         Sex  Age  Height  Weight  Year  Medal
# 0         1   24     180      80  1992      0
# 1         1   23     170      60  2012      0
# 2         1   24     178      75  1920      0
# 3         1   34     181      79  1900      1
# 4         0   21     185      82  1988      0
# ...     ...  ...     ...     ...   ...    ...
# 271111    1   29     179      89  1976      0
# 271112    1   27     176      59  2014      0
# 271113    1   27     176      59  2014      0
# 271114    1   30     185      96  1998      0
# 271115    1   34     185      96  2002      0
#
# [271116 rows x 6 columns]

# %%
corr = data.loc[:, :'Medal'].corr()

plt.figure(figsize=(12, 10))
sns.heatmap(corr, annot=True, vmin=-1.0, cmap='flare')
plt.show()
